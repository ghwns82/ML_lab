# %%
permlist457=[]#엔터 금지!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
one8_perm_ben=[]

with open("ANDROPERM2.txt",'r',encoding='UTF-8') as f:
    while True:
        k = f.readline().replace('\n','')
        if not k:
            break
#         if ".permission." in k:
        if 'name":' in k:
#             if k in one8_perm_ben:
#                 pass
#             else:
            one8_perm_ben.append(k)

list(set(one8_perm_ben))
# Out:
# ['      "name": "android.permission.ACCESS_IMS_CALL_SERVICE",',
#  '      "name": "android.permission.RECEIVE_DATA_ACTIVITY_CHANGE",',
#  '      "name": "android.permission.MANAGE_NOTIFICATIONS",',
#  '      "name": "android.permission.ACCESS_NOTIFICATION_POLICY",',
#  '      "name": "android.permission.CAMERA_SEND_SYSTEM_EVENTS",',
#  '      "name": "android.permission.REAL_GET_TASKS",',
#  '      "name": "android.permission.ACCESS_CONTENT_PROVIDERS_EXTERNALLY",',
#  '      "name": "android.permission.CHANGE_OVERLAY_PACKAGES",',
#  '      "name": "android.permission.RECEIVE_MEDIA_RESOURCE_USAGE",',
#  '      "name": "android.permission.ACCESS_UCE_OPTIONS_SERVICE",',
#  '      "name": "android.permission.READ_USER_DICTIONARY",',
#  '      "name": "android.permission.TRANSMIT_IR",',
#  '      "name": "android.permission.BIND_VR_LISTENER_SERVICE",',
#  '      "name": "android.permission.USE_DATA_IN_BACKGROUND",',
#  '      "name": "android.permission.ACCEPT_HANDOVER",',
# ...

# %%
len(one8_perm_ben)
# Out:
# 457

# %%
middle_lst=[]

for i in one8_perm_ben:
    a=i.split('"')[3]
    middle_lst.append(a)
len(middle_lst)
# Out:
# 457

# %%
for j in middle_lst:
    if j in permlist457:
        pass
    else:
        permlist457.append(j)
len(permlist457)
# Out:
# 457

# %%
permlist457
# Out:
# ['android.intent.category.MASTER_CLEAR.permission.C2D_MESSAGE',
#  'android.permission.ACCEPT_HANDOVER',
#  'android.permission.ACCESS_AMBIENT_LIGHT_STATS',
#  'android.permission.ACCESS_BROADCAST_RADIO',
#  'android.permission.ACCESS_CACHE_FILESYSTEM',
#  'android.permission.ACCESS_CHECKIN_PROPERTIES',
#  'android.permission.ACCESS_COARSE_LOCATION',
#  'android.permission.ACCESS_CONTENT_PROVIDERS_EXTERNALLY',
#  'android.permission.ACCESS_DRM_CERTIFICATES',
#  'android.permission.ACCESS_FINE_LOCATION',
#  'android.permission.ACCESS_FM_RADIO',
#  'android.permission.ACCESS_IMS_CALL_SERVICE',
#  'android.permission.ACCESS_INPUT_FLINGER',
#  'android.permission.ACCESS_INSTANT_APPS',
#  'android.permission.ACCESS_KEYGUARD_SECURE_STORAGE',
#  'android.permission.ACCESS_LOCATION_EXTRA_COMMANDS',
#  'android.permission.ACCESS_LOWPAN_STATE',
#  'android.permission.ACCESS_MOCK_LOCATION',
#  'android.permission.ACCESS_MTP',
#  'android.permission.ACCESS_NETWORK_CONDITIONS',
# ...

# %%
permlist474=[]
with open("C:\\Users\\32171825\\Desktop\\jihyeonnpy\\permlst_jhp.txt",'r') as f:
    while True:
        k = f.readline().replace('\n','')
        if not k:
            break
        permlist474.append(k)

# %%
len(permlist474)
# Out:
# 474

# %%
diff=[]
for i in permlist474:
    if i not in permlist457:
        diff.append(i)
len(diff)
# Out:
# 17

# %%
diff
# Out:
# ['android.permission.READ_OWNER_DATA',
#  'android.permission.WRITE_OWNER_DATA',
#  'android.permission.BACKUP_DATA',
#  'android.permission.ACCESS_USB',
#  'android.permission.GRANT_REVOKE_PERMISSIONS',
#  'android.permission.ACCESS_ALL_EXTERNAL_STORAGE',
#  'android.permission.MAGNIFY_DISPLAY',
#  'android.permission.RETRIEVE_WINDOW_INFO',
#  'android.permission.BIND_CALL_SERVICE',
#  'android.permission.MARK_NETWORK_SOCKET',
#  'android.permission.BROADCAST_SCORE_NETWORKS',
#  'android.permission.CONFIGURE_DISPLAY_COLOR_TRANSFORM',
#  'android.permission.GET_PACKAGE_IMPORTANCE',
#  'android.permission.ACCESS_EPHEMERAL_APPS',
#  'android.permission.BIND_NOTIFICATION_RANKER_SERVICE',
#  'com.android.permission.BIND_EUICC_SERVICE',
#  'com.android.permission.WRITE_EMBEDDED_SUBSCRIPTIONS']

# %%
f=open('permlst_jhp.txt','w')
for name in final_lst:
    f.write(name+'\n')
    
f.close()

# %%
4-114
5-122
6-122
7-122
8-134
9-137
10-140
13-144
14-162
15-165
16-180
17-198
18-206
19-229
21-267
22-276
23-315
24-350
25-351
26-386
27-406
28-457
# Out:
#   File "<ipython-input-117-eb9d5b298c8e>", line 4
#     7-
#       ^
# SyntaxError: invalid syntax

# %%
one8_perm_ben=[]

with open("ANDROPERM.txt",'r',encoding='UTF-8') as f:
    while True:
        k = f.readline().replace('\n','')
        if not k:
            break
        if '"protectionLevel":' in k:
            one8_perm_ben.append(k.split('"')[3])

# %%
len(one8_perm_ben)
# Out:
# 457

# %%
one8_perm_ben
# Out:
# ['signature',
#  'dangerous',
#  'signature|privileged|development',
#  'signature|privileged',
#  'signature|privileged',
#  'signature|privileged',
#  'dangerous|instant',
#  'signature',
#  'signature|privileged',
#  'dangerous|instant',
#  'signature|privileged',
#  'signature|privileged',
#  'signature',
#  'signature|installer|verifier',
#  'signature',
#  'normal',
#  'signature|privileged',
#  'signature',
#  'signature|privileged',
#  'signature|privileged',
#  'normal|instant',
#  'signature|privileged|appop',
#  'normal',
#  'signature',
#  'signature|textClassifier',
#  'signature',
#  'signature|privileged',
#  'signature|privileged',
#  'signature',
#  'signature',
#  'signature|preinstalled',
#  'normal',
#  'normal',
#  'signature',
#  'signature|privileged|development',
#  'signature|privileged',
#  'signature|privileged',
#  'dangerous|runtime',
#  'signature',
#  'signature',
#  'signature',
#  'signature',
#  'signature',
#  'normal',
#  'signature|privileged',
# ...

# %%
here=[]
for i in one8_perm_ben:
    if i in here:
        pass
    else:
        here.append(i)

# %%
here
# Out:
# ['signature',
#  'dangerous',
#  'signature|privileged|development',
#  'signature|privileged',
#  'dangerous|instant',
#  'signature|installer|verifier',
#  'normal',
#  'normal|instant',
#  'signature|privileged|appop',
#  'signature|textClassifier',
#  'signature|preinstalled',
#  'dangerous|runtime',
#  'signature|privileged|vendorPrivileged',
#  'signature|installer',
#  'signature|development|instant|appop',
#  'signature|appop',
#  'signature|setup',
#  'signature|privileged|development|appop',
#  'signature|verifier',
#  'signature|preinstalled|appop|pre23|development',
#  'signature|privileged|installer',
#  'signature|preinstalled|appop|pre23']

# %%
a=0
b=0
c=0
d=0
e=0
f=0
g=0
h=0
ii=0
j=0
k=0
l=0
m=0
n=0
o=0
p=0
q=0
r=0
s=0
t=0
u=0
v=0
w=0
x=0
y=0
for i in one8_perm_ben:
    if i == here[0]:
        a+=1
    elif i == here[1]:
        b+=1
    elif i == here[2]:
        c+=1
    elif i == here[3]:
        d+=1
    elif i == here[4]:
        e+=1 
    elif i == here[5]:
        f+=1
    elif i == here[6]:
        g+=1
    elif i == here[7]:
        h+=1
    elif i == here[8]:
        ii+=1
    elif i == here[9]:
        j+=1
    elif i == here[10]:
        k+=1
    elif i == here[11]:
        l+=1
    elif i == here[12]:
        m+=1
    elif i == here[13]:
        n+=1
    elif i == here[14]:
        o+=1
    elif i == here[15]:
        p+=1
    elif i == here[16]:
        q+=1 
    elif i == here[17]:
        r+=1
    elif i == here[18]:
        s+=1
    elif i == here[19]:
        t+=1
    elif i == here[20]:
        u+=1
    elif i == here[21]:
        v+=1
    elif i == here[22]:
        w+=1
#     elif i == here[23]:
#         x+=1
#     elif i == here[24]:
#         y+=1
result=[a,b,c,d,e,f,g,h,ii,j,k,l,m,n,o,p,q,r,s,t,u,v]
result
# Out:
# [145, 22, 21, 170, 5, 5, 55, 5, 1, 2, 5, 1, 1, 5, 1, 2, 5, 1, 2, 1, 1, 1]

# %% [markdown]
# # group 개수

# %%
cnt=0
with open("ANDROPERM.txt",'r',encoding='UTF-8') as f:
    while True:
        k = f.readline().replace('\n','')
        if '"permissions":' in k:
            break
        if '"name":' in k:
#             print(k)
            cnt+=1
        else:
            pass

# %%
cnt
# Out:
# 10

# %%
one8_perm_ben
# Out:
# ['android.permission.ACCESS_COARSE_LOCATION',
#  'android.permission.ACCESS_FINE_LOCATION',
#  'android.permission.BODY_SENSORS',
#  'android.permission.CALL_PHONE',
#  'android.permission.CAMERA',
#  'android.permission.GET_ACCOUNTS',
#  'android.permission.PROCESS_OUTGOING_CALLS',
#  'android.permission.READ_CALENDAR',
#  'android.permission.READ_CALL_LOG',
#  'android.permission.READ_CELL_BROADCASTS',
#  'android.permission.READ_CONTACTS',
#  'android.permission.READ_EXTERNAL_STORAGE',
#  'android.permission.READ_PHONE_STATE',
#  'android.permission.READ_SMS',
#  'android.permission.RECEIVE_MMS',
#  'android.permission.RECEIVE_SMS',
#  'android.permission.RECEIVE_WAP_PUSH',
#  'android.permission.RECORD_AUDIO',
#  'android.permission.SEND_SMS',
#  'android.permission.USE_SIP',
#  'android.permission.WRITE_CALENDAR',
#  'android.permission.WRITE_CALL_LOG',
#  'android.permission.WRITE_CONTACTS',
#  'android.permission.WRITE_EXTERNAL_STORAGE',
# ...

# %%
real_lst=[]
for i in one8_perm_ben:
    if i in real_lst:
        pass
    else:
        real_lst.append(i)

# %%
len(real_lst)
# Out:
# 28

# %%
one8_perm_ben=[]

with open("ANDROPERM2.txt",'r',encoding='UTF-8') as f:
    while True:
        k = f.readline().replace('\n','')
        if not k:
            break
        else:
            one8_perm_ben.append(k)

# %%
len(one8_perm_ben)
# Out:
# 156

# %%
one7_perm_ben=[]

with open("ANDROPERM2.txt",'r',encoding='UTF-8') as f:
    while True:
        k = f.readline().replace('\n','')
        if not k:
            break
#         if ".permission." in k:
        if "permissionGroup" in k:
            if one8_perm_ben in k:
                pass
            else:
                one7_perm_ben.append(k)
len(one8_perm_ben)
# Out:
# ['      "name": "android.permission-group.ACCOUNTS"',
#  '      "name": "android.permission-group.COST_MONEY"',
#  '      "name": "android.permission-group.DEVELOPMENT_TOOLS"',
#  '      "name": "android.permission-group.HARDWARE_CONTROLS"',
#  '      "name": "android.permission-group.LOCATION"',
#  '      "name": "android.permission-group.MESSAGES"',
#  '      "name": "android.permission-group.NETWORK"',
#  '      "name": "android.permission-group.PERSONAL_INFO"',
#  '      "name": "android.permission-group.PHONE_CALLS"',
#  '      "name": "android.permission-group.STORAGE"',
#  '      "name": "android.permission-group.SYSTEM_TOOLS"']

# %%
one6_perm_ben=[]
with open("ANDROPERM2.txt",'r') as f:
    while True:
        k = f.readline().replace('\n','')
        if not k:
            break
#         if ".permission." in k:
        a= k.split('"')[3]
#         if a in one6_perm_ben:
#             pass
#         else:
        one6_perm_ben.append(a)
len(one6_perm_ben)
# Out:
# 316

# %%
one6_perm_ben
# Out:
# ['android.permission.ACCESS_CHECKIN_PROPERTIES',
#  'android.permission.ACCESS_COARSE_LOCATION',
#  'android.permission.ACCESS_FINE_LOCATION',
#  'android.permission.ACCESS_LOCATION_EXTRA_COMMANDS',
#  'android.permission.ACCESS_MOCK_LOCATION',
#  'android.permission.ACCESS_NETWORK_STATE',
#  'android.permission.ACCESS_SURFACE_FLINGER',
#  'android.permission.ACCESS_WIFI_STATE',
#  'android.permission.BACKUP',
#  'android.permission.BATTERY_STATS',
#  'android.permission.BIND_APPWIDGET',
#  'android.permission.BIND_INPUT_METHOD',
#  'android.permission.BLUETOOTH',
#  'android.permission.BLUETOOTH_ADMIN',
#  'android.permission.BRICK',
#  'android.permission.BROADCAST_PACKAGE_REMOVED',
#  'android.permission.BROADCAST_SMS',
#  'android.permission.BROADCAST_STICKY',
#  'android.permission.BROADCAST_WAP_PUSH',
#  'android.permission.CALL_PHONE',
#  'android.permission.CALL_PRIVILEGED',
#  'android.permission.CAMERA',
#  'android.permission.CHANGE_BACKGROUND_DATA_SETTING',
# ...

# %%
one6_perm_ben=[]
with open("ANDROPERM2.txt",'r') as f:
    while True:
        k = f.readline().replace('\n','')
        if not k:
            break
#         if ".permission." in k:
        a= k.split('"')[3]
        print(a)
        if a in one8_perm_ben:
            pass
        else:
            one6_perm_ben.append(a)
# Out:
# android.permission-group.CALENDAR
# android.permission-group.CALL_LOG
# android.permission-group.CAMERA
# android.permission-group.CONTACTS
# android.permission-group.LOCATION
# android.permission-group.MICROPHONE
# android.permission-group.PHONE
# android.permission-group.SENSORS
# android.permission-group.SMS
# android.permission-group.STORAGE
# android.intent.category.MASTER_CLEAR.permission.C2D_MESSAGE
# android.permission.ACCEPT_HANDOVER
# android.permission.ACCESS_AMBIENT_LIGHT_STATS
# android.permission.ACCESS_BROADCAST_RADIO
# android.permission.ACCESS_CACHE_FILESYSTEM
# android.permission.ACCESS_CHECKIN_PROPERTIES
# android.permission.ACCESS_COARSE_LOCATION
# android.permission.ACCESS_CONTENT_PROVIDERS_EXTERNALLY
# android.permission.ACCESS_DRM_CERTIFICATES
# android.permission.ACCESS_FINE_LOCATION
# android.permission.ACCESS_FM_RADIO
# android.permission.ACCESS_IMS_CALL_SERVICE
# android.permission.ACCESS_INPUT_FLINGER
# android.permission.ACCESS_INSTANT_APPS
# ...

# %%
len(one25_perm_ben)
# Out:
# 398

# %%
one6_perm_ben=[]
with open("ANDROPERM2.txt",'r') as f:
    while True:
        k = f.readline().replace('\n','')
        if not k:
            break
#         if ".permission." in k:
        a= k.split('"')[3]
        print(a)
        if a in one5_perm_ben:
            pass
        else:
            one6_perm_ben.append(a)
# Out:
# android.permission-group.CALENDAR
# android.permission-group.CAMERA
# android.permission-group.CONTACTS
# android.permission-group.LOCATION
# android.permission-group.MICROPHONE
# android.permission-group.PHONE
# android.permission-group.SENSORS
# android.permission-group.SMS
# android.permission-group.STORAGE
# android.intent.category.MASTER_CLEAR.permission.C2D_MESSAGE
# android.permission.ACCESS_CACHE_FILESYSTEM
# android.permission.ACCESS_CHECKIN_PROPERTIES
# android.permission.ACCESS_COARSE_LOCATION
# android.permission.ACCESS_CONTENT_PROVIDERS_EXTERNALLY
# android.permission.ACCESS_DRM_CERTIFICATES
# android.permission.ACCESS_FINE_LOCATION
# android.permission.ACCESS_FM_RADIO
# android.permission.ACCESS_IMS_CALL_SERVICE
# android.permission.ACCESS_INPUT_FLINGER
# android.permission.ACCESS_INSTANT_APPS
# android.permission.ACCESS_KEYGUARD_SECURE_STORAGE
# android.permission.ACCESS_LOCATION_EXTRA_COMMANDS
# android.permission.ACCESS_MOCK_LOCATION
# android.permission.ACCESS_MTP
# ...

# %%
len(one5_perm_ben) # 24level
# Out:
# 538

# %%
one5_perm_ben
# Out:
# ['      "name": "android.permission-group.ACCOUNTS"',
#  '      "name": "android.permission-group.COST_MONEY"',
#  '      "name": "android.permission-group.DEVELOPMENT_TOOLS"',
#  '      "name": "android.permission-group.HARDWARE_CONTROLS"',
#  '      "name": "android.permission-group.LOCATION"',
#  '      "name": "android.permission-group.MESSAGES"',
#  '      "name": "android.permission-group.NETWORK"',
#  '      "name": "android.permission-group.PERSONAL_INFO"',
#  '      "name": "android.permission-group.PHONE_CALLS"',
#  '      "name": "android.permission-group.STORAGE"',
#  '      "name": "android.permission-group.SYSTEM_TOOLS"',
#  '      "name": "android.permission.ACCESS_CHECKIN_PROPERTIES",',
#  '      "name": "android.permission.ACCESS_COARSE_LOCATION",',
#  '      "name": "android.permission.ACCESS_FINE_LOCATION",',
#  '      "name": "android.permission.ACCESS_LOCATION_EXTRA_COMMANDS",',
#  '      "name": "android.permission.ACCESS_MOCK_LOCATION",',
# ...

# %%
ex_list = list(set(ex_list))

# %%
one25_perm_ben=[]
with open("ANDROPERM.txt",'r') as f:
    while True:
        k = f.readline().replace('\n','')
        if not k:
            break
# #         if ".permission." in k:
#         a= k.split('"')[3]
#         if a in one5_perm_ben:
#             pass
#         else:
        k.replace(" ","")
        k.replace("'",'')
        one25_perm_ben.append(k)

# %%
one25_perm_ben
# Out:
# 398

# %%
one25_perm_ben
# Out:
# [" 'android.permission.UPDATE_LOCK',",
#  " 'android.permission.BIND_CONNECTION_SERVICE',",
#  " 'android.permission.FORCE_BACK',",
#  " 'android.permission.SET_TIME_ZONE',",
#  " 'android.permission.BIND_ACCESSIBILITY_SERVICE',",
#  " 'android.permission-group.MESSAGES',",
#  " 'android.permission.WRITE_SMS',",
#  " 'android.permission.SET_SCREEN_COMPATIBILITY',",
#  " 'android.permission.INTERACT_ACROSS_USERS',",
#  " 'android.permission.CAPTURE_VIDEO_OUTPUT',",
#  " 'android.permission.RECOVERY',",
#  " 'android.permission.GET_ACCOUNTS',",
#  " 'android.permission.BIND_TV_REMOTE_SERVICE',",
#  " 'android.permission.STATUS_BAR_SERVICE',",
#  " 'android.permission.UPDATE_DEVICE_STATS',",
#  " 'android.permission.BATTERY_STATS',",
#  " 'android.permission.ACCESS_CHECKIN_PROPERTIES',",
#  " 'android.intent.category.MASTER_CLEAR.permission.C2D_MESSAGE',",
#  " 'android.permission.CAMERA_DISABLE_TRANSMIT_LED',",
#  " 'android.permission-group.WALLPAPER',",
# ...

# %%
one25_perm_ben=list(set(one25_perm_ben))

# %%
one25_perm_ben
# Out:
# [" 'android.permission.UPDATE_LOCK',",
#  " 'android.permission.BIND_CONNECTION_SERVICE',",
#  " 'android.permission.FORCE_BACK',",
#  " 'android.permission.SET_TIME_ZONE',",
#  " 'android.permission.BIND_ACCESSIBILITY_SERVICE',",
#  " 'android.permission-group.MESSAGES',",
#  " 'android.permission.WRITE_SMS',",
#  " 'android.permission.SET_SCREEN_COMPATIBILITY',",
#  " 'android.permission.INTERACT_ACROSS_USERS',",
#  " 'android.permission.CAPTURE_VIDEO_OUTPUT',",
#  " 'android.permission.RECOVERY',",
#  " 'android.permission.GET_ACCOUNTS',",
#  " 'android.permission.BIND_TV_REMOTE_SERVICE',",
#  " 'android.permission.STATUS_BAR_SERVICE',",
#  " 'android.permission.UPDATE_DEVICE_STATS',",
#  " 'android.permission.BATTERY_STATS',",
#  " 'android.permission.ACCESS_CHECKIN_PROPERTIES',",
#  " 'android.intent.category.MASTER_CLEAR.permission.C2D_MESSAGE',",
#  " 'android.permission.CAMERA_DISABLE_TRANSMIT_LED',",
#  " 'android.permission-group.WALLPAPER',",
# ...

# %%
a=[]
for i in range(0,len(one25_perm_ben)):
    one25_perm_ben[i].replace('" ',"")

# %%
one25_perm_ben[0].replace('0','a')
# Out:
# " 'android.permission.UPDATE_LOCK',"

# %%
one19_perm_ben=[]

with open("ANDROPERM.txt",'r') as f:
    while True:
        k = f.readline().replace('\n','')
        if "</manifest>" in k:
            break
#         if ".permission." in k:
        if "android:protectionLevel" in k:
#             if "description":
#                 pass
#             else:
            one19_perm_ben.append(k)
        else:
            pass

# %%
one19_perm_ben
# Out:
# ['        android:protectionLevel="dangerous" />',
#  '        android:protectionLevel="dangerous" />',
#  '        android:protectionLevel="dangerous" />',
#  '        android:protectionLevel="dangerous" />',
#  '        android:protectionLevel="dangerous" />',
#  '        android:protectionLevel="dangerous"/>',
#  '        android:protectionLevel="dangerous" />',
#  '        android:protectionLevel="dangerous" />',
#  '        android:protectionLevel="dangerous" />',
#  '        android:protectionLevel="dangerous" />',
#  '        android:protectionLevel="dangerous" />',
#  '        android:protectionLevel="dangerous" />',
#  '        android:protectionLevel="dangerous" />',
#  '        android:protectionLevel="dangerous" />',
#  '        android:protectionLevel="dangerous" />',
#  '        android:protectionLevel="dangerous" />',
#  '        android:protectionLevel="signature|system" />',
#  '        android:protectionLevel="dangerous" />',
# ...

# %%
with open("ANDROPERM.txt",'r') as f:
    while True:
        k = f.readline().replace('\n','')
        if "</manifest>" in k:
            break
#         if ".permission." in k:
        if "android:protectionLevel" in k:
#             if "description":
#                 pass
#             else:
            one19_perm_ben.append(k)
        else:
            pass

# %%
len(one19_perm_ben)
# Out:
# 313

# %%
len(one19_perm_ben)
# Out:
# 268

# %%
a=[]
for i in range(0,325):
    if one_perm_ben[i] in one3_perm_ben:
        a.append(one_perm_ben[i])

# %%
len(a)
# Out:
# 324
